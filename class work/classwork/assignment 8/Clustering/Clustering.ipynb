# %%
import numpy as np
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans
from matplotlib import pyplot
import pandas as pd
import csv
import os
os.chdir("C:/Users/HYY/Desktop")

# %%
import pandas as pd

data = pd.read_csv("carbon emission.csv", encoding = 'unicode_escape')
x = data
x_np = np.array(x)

# %%
n_clusters = 3                
estimator = KMeans(n_clusters) 
estimator.fit(x)
# Out:
# KMeans(n_clusters=3)

# %%
markers = ['*', 'v', '+', '^', 's']      # List of markup styles
colors = ['r', 'g', 'm', 'c', 'orange']  # List of marker colors
labels = estimator.labels_      # Get cluster labels

pyplot.figure(figsize=(9, 6))
pyplot.title("Carbon emission", fontsize=25)
pyplot.xlabel('Area', fontsize=18)
pyplot.ylabel('Annual carbon emissions (ton)', fontsize=18)

for i in range(n_clusters):    # Iterate over all coordinate points and draw scatter plots
    members = labels == i      # Members is a Boolean array  
    pyplot.scatter(
        x_np[members, 1],      # An array of longitude
        x_np[members, 0],      # An array of latitude
        marker = markers[i],   # Mark style
        c = colors[i]          # Mark color
    )   

pyplot.grid()
pyplot.show()
